# %%
import pandas as pd 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# %%
tr = pd.read_csv('./train.csv')
te = pd.read_csv('./test.csv')

# %%
l_se = []

for i in range(113):
    l_s = tr['sentence'][i].split()
    for j in l_s :
        l_se.append(j)

# %%
l_sl = []
for i in range(113):
    l_s = tr['slots'][i].split()
    for j in l_s :
        l_sl.append(j)

# %%
df_w = pd.DataFrame({'word' : l_se , 'label' : l_sl})

# %%
df_s = pd.DataFrame({'sentence' : tr['sentence'] , 'label' : tr['intent_label']})

# %%
train_data, test_data, train_labels, test_labels = train_test_split(df_w['word'], df_w['label'], test_size=0.2)

# %%
# Define the pipeline
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('svc', SVC())
])

# %%
param_grid = {
    'tfidf__max_features': [1000, 2000, 3000],  # Example parameter for TfidfVectorizer
    'svc__C': [0.1, 1, 10],  # Example parameter for SVC
    'svc__kernel': ['linear', 'rbf']  # Example parameter for SVC
}

# %%
grid_search = GridSearchCV(pipeline, param_grid, cv=3)
grid_search.fit(train_data, train_labels)
# Out:
# C:\Users\Infinity\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                        ('svc', SVC())]),
#              param_grid={'svc__C': [0.1, 1, 10],
#                          'svc__kernel': ['linear', 'rbf'],
#                          'tfidf__max_features': [1000, 2000, 3000]})

# %%
best_estimator = grid_search.best_estimator_

predictions = best_estimator.predict(test_data)

score = accuracy_score(predictions,test_labels)

print('{}% of samples were correctly classified'.format(str(score * 100)))
# Out:
# 80.95238095238095% of samples were correctly classified

# %%
accuracy = accuracy_score(test_labels, predictions)
precision = precision_score(test_labels, predictions, average='weighted')
recall = recall_score(test_labels, predictions, average='weighted')
f1 = f1_score(test_labels, predictions, average='weighted')

# Print the calculated metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Accuracy: 0.8095238095238095
# Precision: 0.7622521129663987
# Recall: 0.8095238095238095
# F1-score: 0.7739919701121203
# C:\Users\Infinity\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Infinity\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Print the predictions and actual labels
print("Predictions:", predictions)
print("Actual Labels:", test_labels.tolist())
# Out:
# Predictions: ['O' 'O' 'B-Billname' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'I-Amount' 'O'
#  'O' 'I-Username' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-Bankname' 'O'
#  'I-amount' 'O' 'O' 'O' 'O' 'O' 'O' 'B-username' 'O' 'B-Billname' 'O'
#  'B-username' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'O' 'B-Billname' 'O' 'O'
#  'B-accountnumber' 'B-Method' 'B-Billname' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'I-Billname' 'B-Billname' 'O' 'O' 'O' 'O' 'B-username' 'O' 'O' 'O'
#  'B-Cartnumber' 'B-Billname' 'O' 'O' 'O' 'O' 'O' 'I-Amount' 'I-Amount'
#  'B-Billname' 'O' 'O' 'O' 'O' 'I-Amount' 'O' 'O' 'O' 'O' 'O' 'O' 'O'
#  'B-Username' 'O' 'O' 'I-Amount' 'I-Billname' 'B-Cartnumber' 'B-Username'
#  'O' 'O' 'I-Billname' 'O' 'O' 'B-Method' 'O' 'I-Billname' 'O' 'O' 'O' 'O'
#  'O' 'O' 'O' 'O' 'I-amount' 'B-Bankname' 'O' 'I-amount' 'O' 'O' 'B-Method'
#  'O' 'O' 'O' 'I-Billname' 'B-Bankname' 'B-Bankname' 'O' 'O' 'O' 'O' 'O'
#  'O' 'B-Amount' 'I-Username' 'O' 'O' 'B-Method' 'O' 'I-Billname' 'O' 'O'
# ...

# %%
train_data_s, test_data_s, train_labels_s, test_labels_s = train_test_split(df_s['sentence'], df_s['label'], test_size=0.15)

# %%
# Define the pipeline
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('svc', SVC())
])

# %%
param_grid = {
    'tfidf__max_features': [1000, 2000, 3000],  # Example parameter for TfidfVectorizer
    'svc__C': [0.1, 1, 10],  # Example parameter for SVC
    'svc__kernel': ['linear', 'rbf']  # Example parameter for SVC
}

# %%
grid_search_s = GridSearchCV(pipeline, param_grid, cv=3)
grid_search_s.fit(train_data_s, train_labels_s)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                        ('svc', SVC())]),
#              param_grid={'svc__C': [0.1, 1, 10],
#                          'svc__kernel': ['linear', 'rbf'],
#                          'tfidf__max_features': [1000, 2000, 3000]})

# %%
best_estimator_s = grid_search_s.best_estimator_

predictions_s = best_estimator_s.predict(test_data_s)

score_s = accuracy_score(predictions_s,test_labels_s)

print('{}% of samples were correctly classified'.format(str(score * 100)))
# Out:
# 80.95238095238095% of samples were correctly classified

# %%
accuracy_s = accuracy_score(test_labels_s, predictions_s)
precision_s = precision_score(test_labels_s, predictions_s, average='weighted')
recall_s = recall_score(test_labels_s, predictions_s, average='weighted')
f1_s = f1_score(test_labels_s, predictions_s, average='weighted')

# Print the calculated metrics
print("Accuracy:", accuracy_s)
print("Precision:", precision_s)
print("Recall:", recall_s)
print("F1-score:", f1_s)
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0

# %%
# Print the predictions and actual labels
print("Predictions:", predictions_s)
print("Actual Labels:", test_labels_s.tolist())
# Out:
# Predictions: ['transaction_card' 'transaction_card' 'transaction_paya'
#  'transaction_paya' 'transaction_card' 'transaction_paya' 'bill_payment'
#  'introduce' 'balance_query' 'balance_query' 'transaction_card'
#  'transaction_card' 'transaction_paya' 'transaction_paya' 'bill_payment'
#  'bill_payment' 'transaction_paya']
# Actual Labels: ['transaction_card', 'transaction_card', 'transaction_paya', 'transaction_paya', 'transaction_card', 'transaction_paya', 'bill_payment', 'introduce', 'balance_query', 'balance_query', 'transaction_card', 'transaction_card', 'transaction_paya', 'transaction_paya', 'bill_payment', 'bill_payment', 'transaction_paya']

# %%
l_f = []
for sen in te['sentence']:
    sena = []
    lps = []
    s = ''
    sena = sen.split()
    lps = best_estimator.predict(sena)
    for g in lps :
        s =  s + str(g) + " "
    l_f.append(s)

# %%
for j in range(80):
    print(te['sentence'][j])
    print(l_f[j])
    print('-------------------')
    print('\n')
# Out:
# میخواهم مبلغ 50 هزار تومن را از حساب ملت با شماره 48759214 به حساب رضا احمدی کارت به کارت کنم درضمن تاریخ انقضای کارت 02/06 هست اما 5 هزار تومن کم دارم لطف میکنی انجام بدی جبران میکنم
# O O B-Amount I-Amount I-Amount O O O B-Bankname O O B-Accountnumber O O B-Username I-Username O O O O O O O O B-exprdate O O O I-Amount I-Amount O O O O O O O O
# -------------------
#
#
# نتقال مبلغ 70 میلیون ریال از حساب اصلی سپه‌ام به شماره 5677889976 به کارت اقتصاد نوینم
# O O O I-amount O O O O B-Bankname O O O O O O O
# -------------------
#
#
# مبلغ صد میلیون تومان از شماره حساب 2356049 بانک صادرات به نام سعید صادقی به شماره شبا IR789541000056210781007836 به نام حسین صالحی بانک کشاورزی منتقل گردد
# O B-Amount I-amount I-Amount O O O B-accountnumber O B-Bankname O O O O O O O B-iban O O B-Username O O O O O
# -------------------
#
#
# میشه موجودی حساب ملی را بگی
# O O O B-Bankname O O
# -------------------
#
#
# ...

# %%
lpsf = best_estimator_s.predict(te['sentence'])

# %%
for o in range(80):
    print(te['sentence'][o])
    print(lpsf[o])
    print('-------------------')
    print('\n')
# Out:
# میخواهم مبلغ 50 هزار تومن را از حساب ملت با شماره 48759214 به حساب رضا احمدی کارت به کارت کنم درضمن تاریخ انقضای کارت 02/06 هست اما 5 هزار تومن کم دارم لطف میکنی انجام بدی جبران میکنم
# transaction_card
# -------------------
#
#
# نتقال مبلغ 70 میلیون ریال از حساب اصلی سپه‌ام به شماره 5677889976 به کارت اقتصاد نوینم
# transaction_card
# -------------------
#
#
# مبلغ صد میلیون تومان از شماره حساب 2356049 بانک صادرات به نام سعید صادقی به شماره شبا IR789541000056210781007836 به نام حسین صالحی بانک کشاورزی منتقل گردد
# transaction_card
# -------------------
#
#
# میشه موجودی حساب ملی را بگی
# balance_query
# -------------------
#
#
# شماره حساب بانک ملت من 87897 است شبای آقای اضغری IR7879 است میتونی از حساب من به آقای اصغری 15 میلیون بریزی
# balance_query
# -------------------
#
#
# من حسام حسینی هستم
# introduce
# -------------------
#
#
# میخواهم از حساب ملتم قبض آب را پرداخت کنم
# bill_payment
# -------------------
#
#
# ...

# %%
dff = pd.DataFrame({'slots' : l_f , 'intent_label': lpsf})

# %%
dff.to_csv('predictions1.csv' , index = True  ) #index
